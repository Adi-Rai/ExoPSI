# %%
from ExoPSI import exopsi
import pandas as pd
exopsi = exopsi()

# %%
df = pd.read_excel(r"Test Dataset.xlsx") 
print(df)
# Out:
#       Unnamed: 0    P. Name P. Composition Class P. Atmosphere Class  \
# 0              0      Earth                Rocky                 Yes
# 1              1       Mars                Rocky                 Yes
# 2              2       Moon                Rocky                 Yes
# 3              3      Venus                Rocky                 Yes
# 4              4      Titan                Rocky                 Yes
# ...          ...        ...                  ...                 ...
# 3356        3356     XO-3 b                  gas                 NaN
# 3357        3357     XO-4 b                  gas                 NaN
# 3358        3358     XO-5 b                  gas                 NaN
# 3359        3359  YBP1194 b                  gas                 NaN
# 3360        3360  YBP1514 b                  gas                 NaN
#
#         P.Mass(kg)  P. Radius (EU)  P. Density (EU)  P. Esc Vel (EU)  \
# 0       5.97*10^24           1.000            1.000            1.000
# 1     0.0642*10^24           0.532            0.713            0.450
# 2      0.073*10^24           0.272            0.606            0.213
# 3      0.487*10^24           0.950            0.951            0.926
# 4       0.13*10^24           0.404            0.340            0.235
# ...            ...             ...              ...              ...
# 3356           NaN          13.630            1.480           16.580
# 3357           NaN          14.750            0.160            5.900
# 3358           NaN          11.540            0.220            5.450
# 3359           NaN           7.970            0.210            3.680
# 3360           NaN           8.340            0.220            3.910
#
#       P. Teq Mean (K)  P. Ts Mean (K)  ... P. Surf Press (EU)  \
# 0                 NaN           288.0  ...                NaN
# 1                 NaN           240.0  ...                NaN
# 2                 NaN           197.0  ...                NaN
# 3                 NaN           730.0  ...                NaN
# 4                 NaN            94.0  ...                NaN
# ...               ...             ...  ...                ...
# 3356              NaN          1705.5  ...                NaN
# 3357              NaN          1336.0  ...                NaN
# 3358              NaN          1133.5  ...                NaN
# 3359              NaN           944.5  ...                NaN
# 3360              NaN           984.8  ...                NaN
#
#       P. Period (days)  P. Mean Distance (AU)  Distance (Km)  S. Mass (SU)  \
# 0                  NaN                    NaN            NaN           NaN
# 1                  NaN                    NaN            NaN           NaN
# 2                  NaN                    NaN            NaN           NaN
# 3                  NaN                    NaN            NaN           NaN
# 4                  NaN                    NaN            NaN           NaN
# ...                ...                    ...            ...           ...
# 3356              3.19                   0.04            NaN          1.41
# 3357              4.12                   0.05            NaN          1.32
# 3358              4.19                   0.05            NaN          0.88
# 3359              6.96                   0.07            NaN          1.01
# 3360              5.12                   0.05            NaN          0.96
#
#        S.Mass (Kg)  Rev (Days)  ESI (Ve)   P.Mass (Kg)  Distance(Km)
# 0              NaN         NaN       NaN           NaN           NaN
# 1              NaN         NaN       NaN           NaN           NaN
# 2              NaN         NaN       NaN           NaN           NaN
# 3              NaN         NaN       NaN           NaN           NaN
# 4              NaN         NaN       NaN           NaN           NaN
# ...            ...         ...       ...           ...           ...
# 3356  2.791800e+30         NaN  0.218377  2.238610e+28     5984000.0
# 3357  2.613600e+30         NaN  0.420268  3.068354e+27     7480000.0
# 3358  1.742400e+30         NaN  0.440584  2.044932e+27     7480000.0
# 3359  1.999800e+30         NaN  0.551504  6.455732e+26    10472000.0
# 3360  1.900800e+30         NaN  0.533291  7.595190e+26     7480000.0
#
# [3361 rows x 40 columns]

# %%
upper_lims=[1.9, 1.5,1.4,323]
lower_lims = [0.5, 0.7,0.4,273]
ref_val = [1,1,1,288]
weights = exopsi.calc_weight(ref_val,upper_lims,lower_lims)
print(weights)
# Out:
# The calculated weight(s) is(are): [0.57, 1.07, 0.7, 5.58]
# None

# %%
PSI_data = exopsi.calc_psi(df.iloc[:,[5,6,7,9]],upper_lims,lower_lims,ref_val,0.8,surf_param=['P. Esc Vel (EU)','P. Ts Mean (K)'],int_param=['P. Radius (EU)','P. Density (EU)'],p_index=df.loc[:,'P. Name'])
print(PSI_data)
# Out:
#          P.Name  PSI_P. Radius (EU)  PSI_P. Density (EU)  PSI_P. Esc Vel (EU)  \
# 0         Earth            1.000000             1.000000             1.000000
# 1          Mars            0.812380             0.821840             0.716163
# 2          Moon            0.616217             0.739946             0.480711
# 3         Venus            0.985303             0.973150             0.972947
# 4         Titan            0.729836             0.483930             0.508512
# ...         ...                 ...                  ...                  ...
# 3356     XO-3 b            0.321661             0.794399             0.218377
# 3357     XO-4 b            0.308416             0.252081             0.420268
# 3358     XO-5 b            0.351202             0.335807             0.440584
# 3359  YBP1194 b            0.425104             0.322327             0.551504
# 3360  YBP1514 b            0.415422             0.335807             0.533291
#
#       PSI_P. Ts Mean (K)  PSI_Interior  PSI_Surface  PSI_Global
# 0               1.000000      1.000000     1.000000    1.000000
# 1               0.587528      0.817096     0.648665    0.728026
# 2               0.313639      0.675254     0.388291    0.512050
# 3               0.041680      0.979208     0.201376    0.444060
# 4               0.019138      0.594298     0.098650    0.242132
# ...                  ...           ...          ...         ...
# 3356            0.000980      0.505497     0.014629    0.085994
# 3357            0.003077      0.278829     0.035961    0.100134
# 3358            0.006469      0.343418     0.053387    0.135403
# 3359            0.014341      0.370165     0.088933    0.181439
# 3360            0.011984      0.373499     0.079943    0.172797
#
# [3361 rows x 8 columns]

# %%
exopsi.psi_dist(PSI_data)

# %%
print(df.iloc[:,[5,6,7]])
mars_data = exopsi.unit_conv(df.iloc[:,[5,6,7]],[0.53,0.71,0.45])
mars_data
# Out:
#       P. Radius (EU)  P. Density (EU)  P. Esc Vel (EU)
# 0              1.000            1.000            1.000
# 1              0.532            0.713            0.450
# 2              0.272            0.606            0.213
# 3              0.950            0.951            0.926
# 4              0.404            0.340            0.235
# ...              ...              ...              ...
# 3356          13.630            1.480           16.580
# 3357          14.750            0.160            5.900
# 3358          11.540            0.220            5.450
# 3359           7.970            0.210            3.680
# 3360           8.340            0.220            3.910
#
# [3361 rows x 3 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\ExoPSI\Aditya_Testing\Test notebook.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/ExoPSI/Aditya_Testing/Test%20notebook.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> print(df.iloc[:,[5,6,7]])
# ----> <a href='vscode-notebook-cell:/e%3A/ExoPSI/Aditya_Testing/Test%20notebook.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> mars_data = exopsi.unit_conv(df.iloc[:,[5,6,7]],[0.53,0.71,0.45])
#       <a href='vscode-notebook-cell:/e%3A/ExoPSI/Aditya_Testing/Test%20notebook.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> mars_data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ExoPSI\exopsi.py:198, in exopsi.unit_conv(data, ref_index, unit_name)
#     196 def unit_conv(data,ref_index,unit_name):
#     197     unit_conv_df = pd.DataFrame()
# --> 198     for j in data.index:
#     199         k=0
#     200         for i in data.columns:
#
# AttributeError: 'exopsi' object has no attribute 'index'

# %%
exopsi.psi_scale(PSI_data)
# Out:
# C:\Users\mailm\AppData\Roaming\Python\Python39\site-packages\ExoPSI\exopsi.py:84: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(data_x, data_y, cmap="viridis")
